# %%
import numpy as np
a = np.array([1,2,3,4])
print (a)
# Out:
# [1 2 3 4]

# %% [markdown]
# #### Vectorized version runs 300 times faster than non-vectorized version. Whenever possible, avoid explicit for-loops

# %%
import time

a = np.random.rand(1000000)
b = np.random.rand(1000000)

tic = time.time()
c = np.dot(a,b)
toc = time.time()

print(c)
print("Vectorized version:" + str(1000*(toc-tic)) +"ms")
# Out:
# 249775.944432
# Vectorized version:1.3098716735839844ms

# %%
c = 0
tic = time.time()
for i in range(1000000):
    c += a[i]*b[i]
toc = time.time()

print(c)
print("For loop:" + str(1000*(toc-tic)) + "ms")
# Out:
# 249775.944432
# For loop:572.1349716186523ms

# %% [markdown]
# #### Exponential operation on every element of a matrix / vector

# %%
v = np.array([1,2,3,4])
u = np.exp(v)
u
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692,  54.59815003])

# %% [markdown]
# #### Vectorize Logistic Regression

# %%
# Z = np.dot(wT,X) + b

# %%
# Z = wTX + b = np.dot(w.T,X)+b
# A = sig(Z)
# dZ = A - Y
# dw = 1/mXdZT
# db = 1/m np.sum(dZ)

# %%
from IPython.display import Image
Image(filename='implementing logistic regression.png')

# %% [markdown]
# #### Broadcasting Example

# %%
import numpy as np

A = np.array([[56.0,0.0,4.4,68.0],
              [1.2,104.0,52.0,8.0],
              [1.8,135.0,99.0,0.9]])

print(A)
# Out:
# [[  56.     0.     4.4   68. ]
#  [   1.2  104.    52.     8. ]
#  [   1.8  135.    99.     0.9]]

# %%
cal = A.sum(axis=0) # axis=0, sums vertically
print(cal)
# Out:
# [  59.   239.   155.4   76.9]

# %%
percentage = 100*A/cal
print(percentage)
# Out:
# [[ 94.91525424   0.           2.83140283  88.42652796]
#  [  2.03389831  43.51464435  33.46203346  10.40312094]
#  [  3.05084746  56.48535565  63.70656371   1.17035111]]

# %% [markdown]
# #### Python Numpy Vectors

# %%
a = np.random.rand(5)
print(a)
# Out:
# [ 0.01068404  0.52073838  0.30904172  0.47598429  0.8929423 ]

# %%
a.shape
# Out:
# (5,)

# %%
print(a.T)
# Out:
# [ 0.01068404  0.52073838  0.30904172  0.47598429  0.8929423 ]

# %%
print(np.dot(a,a.T))
# Out:
# 1.39069638534

# %%
a = np.random.randn(5,1)
print(a)
# Out:
# [[ 0.80072696]
#  [ 0.5987103 ]
#  [ 1.14988354]
#  [-0.76153972]
#  [ 0.87367553]]

# %%
print(a.T)
# Out:
# [[ 0.80072696  0.5987103   1.14988354 -0.76153972  0.87367553]]

# %%
print(np.dot(a,a.T))
# Out:
# [[ 0.64116367  0.47940348  0.92074275 -0.60978538  0.69957555]
#  [ 0.47940348  0.35845403  0.68844712 -0.45594167  0.52307854]
#  [ 0.92074275  0.68844712  1.32223215 -0.87568198  1.00462511]
#  [-0.60978538 -0.45594167 -0.87568198  0.57994274 -0.66533862]
#  [ 0.69957555  0.52307854  1.00462511 -0.66533862  0.76330893]]

# %% [markdown]
# #### Week 2 Quiz

# %%
# question 4
a = np.random.randn(2, 3) # a.shape = (2, 3)
b = np.random.randn(2, 1) # b.shape = (2, 1)
c = a + b
print (c)
# Out:
# [[-0.14053977 -0.69544103  1.63368964]
#  [ 0.20510341 -1.41150879 -0.12084296]]

# %%
# question 5
a = np.random.randn(4, 3) # a.shape = (4, 3)
b = np.random.randn(3, 2) # b.shape = (3, 2)
c = a*b
print (c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3753dbdd3574> in <module>()
#       2 a = np.random.randn(4, 3) # a.shape = (4, 3)
#       3 b = np.random.randn(3, 2) # b.shape = (3, 2)
# ----> 4 c = a*b
#       5 print (c)
#
# ValueError: operands could not be broadcast together with shapes (4,3) (3,2)

# %%
# question 7
a = np.random.randn(12288, 150) # a.shape = (12288, 150)
b = np.random.randn(150, 45) # b.shape = (150, 45)
c = np.dot(a,b)
c.shape
# Out:
# (12288, 45)

# %%
a = np.random.randn(3, 3)
b = np.random.randn(3, 1)
c = a*b
print (c)
# Out:
# [[ 0.00176456  0.20519808 -0.5309181 ]
#  [-0.04856473  1.19664136  0.11372851]
#  [ 0.1771275   0.05237302 -0.29370675]]

# %% [markdown]
# #### Week 3 Quiz

# %%
import numpy as np
A = np.random.randn(4,3)
B = np.sum(A, axis=1, keepdims=True)
print(A)
print(B)
print(B.shape)
# Out:
# [[-0.04760286 -0.83147978 -0.10147394]
#  [ 0.46112427 -0.79621876  0.3034779 ]
#  [ 0.26233753 -0.54437142 -0.85872149]
#  [-0.3664426  -1.3941324  -0.53648472]]
# [[-0.98055659]
#  [-0.0316166 ]
#  [-1.14075537]
#  [-2.29705972]]
# (4, 1)

# %%
A,
